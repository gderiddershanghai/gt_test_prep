# %% [markdown]
# ## Supply Chain Practice Test
#
# ---
#
# ### **Question 1**
# **When is a Decentralized Supply Chain more appropriate?**
#
# - A. When there is a low distribution cost per weight
# - B. When you need less customized delivery
# - C. When demand is more predictable
# - D. When you are not as worried about lead times
# - E. When there are many points of sale
#
# ---
#
# ### **Question 2**
# **How do Efficient and Responsive supply chains relate to Centralized vs Decentralized strategies? Select all that apply.**
#
# - A. A centralized strategy needs an efficient supply chain
# - B. A centralized strategy needs a responsive supply chain
# - C. A decentralized strategy needs an efficient supply chain
# - D. A decentralized strategy needs a responsive supply chain
# - E. There is no correct answer here
#
# ---
#
# ### **Question 3**
# **Which of the following are pitfalls to Offshoring? Select all that apply.**
#
# - A. You may lose the ability to do the task offshore
# - B. Exchange rates can be volatile
# - C. You give up some control over quality and cost
# - D. You may not get a very detailed understanding on your overall product cost
#
# ---
#
# ### **Question 4**
# **Which one of the following is NOT a cost factor when considering offshoring that is not captive?**
#
# - A. Export taxes
# - B. Exchange rate exposure
# - C. Real Estate costs
# - D. Damage in transit
# - E. Ocean transport costs
#
# ---
#
# ### **Question 5**
# **Which conditions are more conducive to a Centralized supply chain? Select all that apply.**
#
# - A. Demand is stable
# - B. You need higher product availability
# - C. Many points of sale
# - D. Low distribution complexity
#
# ---
#
# ### **Question 6**
# **Which of these is NOT a cost driver for offshoring?**
#
# - A. Exchange rate fluctuations
# - B. Falling communication costs
# - C. Cost of risk in joint ventures
# - D. Labor costs

# %% [markdown]
# ---
# ---
# ---
# ---

# %% [markdown]
# ### **Question 7**
# **Which features typically indicate a need for a Responsive Supply Chain?**
# *Select all that apply.*
#
# - A. Rapid shifts in customer preferences
# - B. Emphasis on cost efficiency
# - C. Short product lifecycle
# - D. Minimal product customization
# - E. High forecast uncertainty
#
# ---
#
# ### **Question 8**
# **Which conditions typically justify decentralizing a supply chain network?**
# *Select all that apply.*
#
# - A. Long lead times are acceptable
# - B. Multiple regions require tailored delivery
# - C. Low transportation cost per unit
# - D. Products are time-sensitive
# - E. Demand is erratic and localized
#
# ---
#
# ### **Question 9**
# **A company offshores part of its production. Which risks should it evaluate?**
# *Select all that apply.*
#
# - A. Intellectual property leakage
# - B. Increased wage inflation at home
# - C. Supply chain disruption due to distance
# - D. Exchange rate exposure
# - E. Higher domestic labor union costs
#
# ---
#
# ### **Question 10**
# **Which of the following is least likely to be true of a centralized network?**
#
# - A. Requires fewer warehouses
# - B. Benefits from high shipping volume discounts
# - C. Highly responsive to local market fluctuations
# - D. Easier to standardize processes
#
# ---
#
# ### **Question 11**
# **Which of the following is a hidden cost that can reduce the benefit of offshoring?**
#
# - A. High domestic salaries
# - B. Exchange rate volatility
# - C. Low-cost air freight
# - D. Domestic labor laws
#
# ---
#
# ### **Question 12**
# **What is a major risk of offshoring core competencies?**
#
# - A. Loss of branding
# - B. Lower logistics costs
# - C. Longer domestic work hours
# - D. Weakening the company’s strategic capabilities
#
# ---
#
# ### **Question 13**
# **Centralized supply chains typically align with which supply chain model?**
#
# - A. Responsive
# - B. Agile
# - C. Efficient
# - D. Flexible
#
# ---
#
# ### **Question 14**
# **Which pair best matches supply chain strategy with product type?**
#
# - A. Functional product – Agile supply chain
# - B. Innovative product – Efficient supply chain
# - C. Innovative product – Responsive supply chain
# - D. Functional product – Decentralized supply chain

# %% [markdown]
# ---
# ---
# ---
# ---

# %% [markdown]
# ### **Question 15**
# The formula used to calculate the optimal order quantity in a newsvendor setting depends on:
# - A. Total yearly revenue
# - B. Reorder lead time
# - C. Critical fractile based on overage and underage cost
# - D. Holding cost only
#
# ---
#
# ### **Question 16**
# Which assumption *does not* apply to the basic EOQ model?
# - A. Demand is constant
# - B. Replenishment is instantaneous
# - C. Shortages are allowed
# - D. Only ordering and holding costs matter
#
# ---
#
# ### **Question 17**
# In the EOQ formula, what happens if holding cost (H) increases?
# - A. EOQ increases
# - B. EOQ decreases
# - C. EOQ stays the same
# - D. EOQ drops to zero
#
# ---
#
# ### **Question 18**
# EOQ is calculated by minimizing which two costs?
# - A. Setup and shrinkage
# - B. Holding and ordering
# - C. Spoilage and backorders
# - D. Procurement and transportation
#
# ---
#
# ### **Question 19**
# Why does a 100% fill rate usually lead to high holding costs?
# - A. Because it requires bulk purchasing discounts
# - B. Because more frequent deliveries are needed
# - C. Because excess inventory is kept to avoid stockouts
# - D. Because low fill rates are more expensive
#
# ---
#
# ### **Question 20**
# In the case, why is the cost of underage for Great White estimated as (Retail – Wholesale)?
# - A. It represents the lost margin on a missed sale
# - B. It’s equivalent to total annual sales
# - C. It’s the customer loyalty penalty
# - D. It matches the overage cost

# %% [markdown]
# ---
# ---
# ---
# ---

# %% [markdown]
# ### Question 21
# **Kimberly sells 400 kimonos per month. The ordering cost is \$40 per order, and the holding cost is \$10 per kimono per year. What is the Economic Order Quantity (EOQ)?**
# - 186
# - 176
# - 196
# - 166
# - 156
#
# ---
#
# ### Question 22
# **Continuing with Rob's Exotic But Cheap Motors, at the end of the year, Rob's total sales were 7,920 cars — 330 cars fewer than his forecast. In planning for the next year, Rob analyzed 20 years of historical data and found that annual demand is approximately normally distributed with a mean of 7,950 cars and a standard deviation of 280 cars. Rob uses a 90% service level (Z = 1.29). Given an ordering cost of \$20,000 per order and a holding cost of \$700 per car per year, what is Rob's optimal reorder point (ROP)? Assume 360 auction days in a year and a lead time of 12 days.**
# - 331
# - 269
# - 265
# - 360
#
# ---
#
# ### Question 23
# **DJ’s Drone Store sells 1,000 drones per year. The ordering cost is \$10 per order, and the annual holding cost is \$0.50 per unit. What is the Economic Order Quantity (EOQ)?**
# - 100
# - 150
# - 200
# - 250
# - 300
#
# ---
#
# ### Question 24
# **What is the main purpose of a pull system in Lean operations?**
# - A. To maximize machine utilization
# - B. To reduce idle time of workers
# - C. To produce only when there is downstream demand
# - D. To ensure every worker is constantly busy
#
# ---
#
# ### Question 25
# **(True/False)**
# In a pull system, inventory levels are typically higher than in a push system to prevent stockouts.
# - True
# - False
#
# ---
#
# ### Question 26
# **Which of the following best reflects Lean thinking?**
# - A. Minimizing lead time by batching large orders
# - B. Balancing labor efficiency with excess inventory
# - C. Producing at the rate of customer demand
# - D. Prioritizing equipment utilization above all else
#
# ---
#
# ### Question 27
# **(True/False)**
# One risk of a push system is overproduction, which leads to increased holding costs and potential waste.
# - True
# - False
#
# ---
#
# ### Question 28
# **Which of the following strategies is considered a demand-side lever to balance supply and demand?**
# - A. Hiring more workers
# - B. Using overtime
# - C. Running a time-limited discount
# - D. Increasing order frequency

# %% [markdown]
# ___
# ___
# ___
# ___

# %% [markdown]
# ### Question 28   (b - unrelated to previous 28)
# **Which of the following best describes the critical fractile in the newsvendor model?**
# - A. The average number of units sold
# - B. The ratio of underage cost to total marginal cost
# - C. The expected demand
# - D. The maximum inventory level allowed
#
# ---
#
# ### Question 29
# **The critical fractile equals 0.80. What is the implied overage-to-underage cost ratio $CO:CU$?**
# - A. 1 : 4
# - B. 1 : 3
# - C. 1 : 1
# - D. 4 : 1
#
# ---
#
# ### Question 30
# **A wholesaler plans to buy back unsold inventory at 40% of the retailer’s purchase cost. How does this buy-back influence the retailer’s critical fractile?**
# - A. Decreases it
# - B. Increases it
# - C. Leaves it unchanged
# - D. Eliminates its use
#
# ---
#
# ### Question 31
# **Which metric best quantifies amplification in the bullwhip effect?**
# - A. Mean absolute deviation of demand
# - B. Fill rate differential
# - C. Variance ratio of orders to sales
# - D. Lead-time demand
#
# ---
#
# ### Question 32
# **A company can buy a part at 12 USD per unit or receive a discount to 10 USD per unit if it orders 2,500 units at once. Ordering cost is 100 USD per order, and holding cost is 20% of unit price. Annual demand is 5,000 units. What should the company do?**
# - A. Use the \$12 supplier
# - B. Use the \$10 supplier
# - C. Use either—cost is the same
# - D. Use \$10 supplier only if EOQ ≥ 2,500
# - E. Use \$10 supplier if total cost is minimized
#
# ---
#
# ### Question 33
# **A store buys each T-shirt for 25 USD and sells it for 40 USD. Unsold shirts are donated (no salvage value). What is the critical fractile?**
# - A. 0.30
# - B. 0.60
# - C. 0.45
# - D. 0.75
# - E. None of the above

# %% [markdown]
# ___
# ___
# ___
# ___

# %% [markdown]
# ### Question 33  (b no relation)
# **Where would the newsvendor model be least useful?**
#
# - A. Perishable items
# - B. Items with a short selling season
# - C. Items with a long selling season
# - D. Newspapers
#
# ---
#
# ### Question 34
# **What is the critical fractile for a newsboy who buys papers for USD 0.75 and sells them on the street corner for USD 1.25. He has a standing agreement with the local animal boarding facility to sell papers for USD 0.10 each.**
#
# - A. 0.35
# - B. 0.56
# - C. 0.43
# - D. 0.75
# - E. 0.62
#
# ---
#
# ### Question 35
# **The ABC Widget Integrated Supply Chain**
#
# A multi-tiered supply chain consists of a Wholesaler (W), a Retailer (R), and a Manufacturer (M). The Wholesaler supplies a product to a Retailer (R), who sells to end Customers (C).
#
# - C pays R: USD 11.50
# - R pays W: USD 4.50
# - W pays M: USD 2.25
# - M’s cost: USD 1.00
#
# Unsold widgets have no salvage value.
#
# **What is the optimal service level for the integrated supply chain?**
#
# - A. 38%
# - B. 62%
# - C. 79%
# - D. 91%
# - E. 24%
#
# ---
#
# ### Question 36
# **Continuing with the ABC Widget Integrated Supply Chain scenario, what is R’s optimal service level?**
#
# - A. 86%
# - B. 83%
# - C. 61%
# - D. 92%
#
# ---
#
# ### Question 37
# **Continuing with the Widget Integrated Supply Chain scenario: R finds a scrap dealer that will buy all unsold widgets for USD 0.50. What is R’s new optimal service level?**
#
# - A. 32%
# - B. 72%
# - C. 34%
# - D. 64%
# - E. 14%
#
# ---
#
# ### Question 38
# **Jimmy sells a highly perishable product to dock workers at the Port of Miami.**
#
# - Cost: USD 4.20
# - Selling price: USD 10.00
# - Retail fallback cost: USD 8.90
# - Demand ~ Normal(75, 16)
#
# He runs to buy product at retail when stockouts occur; otherwise, unsold units are discarded.
#
# **What is Jimmy’s optimal service level (round up to the next full percent)?**
#
# - A. 58%
# - B. 51%
# - C. 48%
# - D. 53%
# - E. 65%
#
# ---
#
# ### Question 39
# **Bob sells a highly perishable food product to construction workers.**
#
# - Cost: USD 4.50
# - Selling price: USD 11.00
# - If out of stock, Bob fulfills demand by purchasing at retail and adds USD 1 for margin
# - Unsold items are discarded
# - Demand ~ Normal(175, 32)
#
# **What is Bob’s optimal service level (round up to the next full percent)?**
#
# - A. 43%
# - B. 37%
# - C. 50%
# - D. 55%
# - E. 53%
#
# ---
#
# ### Question 40
# **Bill's Bookstore places orders for wall calendars in lots of 10 units at USD 27 per lot.**
#
# Calendars sell for USD 5.79 each. Unsold calendars are sold for USD 0.50 each. Demand follows the discrete distribution below:
#
# | Demand (units) | Probability |
# |----------------|-------------|
# | 10 or less     | 0.30        |
# | 11–20          | 0.25        |
# | 21–30          | 0.20        |
# | 31–40          | 0.15        |
# | 41–50          | 0.10        |
#
# **How many calendars should Bill order to meet the optimal service level?**
#
# - A. 10
# - B. 20
# - C. 30
# - D. 40
# - E. 50

# %% [markdown]
# ___
# ___
# ___
# ___

# %% [markdown]
# ### Question 41
# **Critical-Fractile Calculation**
# A newsboy buys papers for USD 0.75 each and sells them on the street for USD 1.25. Unsold papers are sold to a local animal-boarding facility for USD 0.10 each.
# What is the newsboy’s critical fractile?
#
# - 0.35
# - 0.56
# - 0.43
# - 0.75
# - 0.62
#
# ---
#
# ### Question 42
# **ABC Widget Integrated Supply Chain – Integrated Service Level**
# Supply-chain structure:
# - Customer pays Retailer (R) = USD 11.50 per unit
# - Retailer pays Wholesaler (W) = USD 4.50 per unit
# - Wholesaler pays Manufacturer (M) = USD 2.25 per unit
# - Manufacturer’s production cost = USD 1.00 per unit
# Unsold widgets have **zero salvage value**.
# What is the optimal service level for the integrated supply chain (C-R-W-M combined)?
#
# - 38 %
# - 62 %
# - 79 %
# - 91 %
# - 24 %
#
# ---
#
# ### Question 43
# **Retailer Service Level with Scrap Salvage**
# Using the same ABC Widget scenario, the retailer (R) can now sell all unsold widgets to a scrap dealer for **USD 0.50 each**.
# What is R’s new optimal service level?
#
# - 32 %
# - 72 %
# - 34 %
# - 64 %
# - 14 %
#
# ---
#
# ### Question 44
# **Global-Sourcing Drivers**
# Which of the following is **not** a reason companies pursue offshore opportunities?
#
# - Lower comparative cost factors such as labor and materials
# - More trade regulations and tariffs
# - Increased foreign competition at home
# - Need for faster response and customization
#
# ---
#
# ### Question 45
# **Overage-Cost Statements in the Newsvendor Model**
# In the newsvendor notation (P = selling price, C = unit acquisition cost, S = salvage value, D = demand), which statement(s) are **true**? (Select all that apply.)
#
# - The cost of being over is C − S
# - The cost of being over is (C − S) × D
# - The cost of being over is P − C
# - The cost of being over is (P − C) × D
# - The cost of being over is P − S
# - The cost of being over is (P − S) × D
#
# ---
#
# ### Question 46
# **Roscoe’s Flower Stand – Optimal Service Level**
# Roscoe buys flower bunches each morning at **USD 3.90** and sells them for **USD 7.00**. Unsold bunches are donated (no salvage). Daily demand is Normal(mean = 62, σ = 15).
# What is Roscoe’s optimal service level? (Round **up** to the next full percent.)
#
# - 18 %
# - 52 %
# - 45 %
# - 37 %
# - 59 %
#
# ---
#
# ### Question 47
# **Fiske Spinner – Total Annual Inventory Cost**
# Data for the Fiske Spinner component:
#
# - Product cost = USD 24.75 per unit
# - Annual demand = 4 500 units
# - Order cost = USD 275 per order
# - Holding cost = 10 % of product cost per year
# - Safety stock = 50 units
#
# Using EOQ (round up the number of orders to the nearest whole order), what is the **total annual inventory cost** (ordering cost + holding cost on cycle stock + holding cost on safety stock)?
#
# - USD 2 613
# - USD 2 736
# - USD 1 375
# - USD 24 750
# - USD 2 475

# %% [markdown]
# ___
# ---
# ---

# %% [markdown]
# ### Question 48
# A bookstore tracks notebook sales:
#
# | Year | Sales |
# |------|-------|
# | 2014 | 450 |
# | 2015 | 495 |
# | 2016 | 518 |
# | 2017 | 563 |
# | 2018 | 584 |
# | 2019 | ? |
#
# Using a **3-period simple moving average**, what is the forecast for 2019?
#
# - 480
# - 460
# - 507
# - 520
# - 555
#
# ---
#
# ### Question 49
# Using the same data set:
#
# | Year | Sales |
# |------|-------|
# | 2014 | 450 |
# | 2015 | 495 |
# | 2016 | 518 |
# | 2017 | 563 |
# | 2018 | 584 |
#
# Compute the **3-period simple moving-average forecast for 2017**.
#
# - 460
# - 480
# - 488
# - 507
# - 520
#
# ---
#
# ### Question 50
# Using the notebook sales again:
#
# | Year | Sales |
# |------|-------|
# | 2014 | 450 |
# | 2015 | 495 |
# | 2016 | 518 |
# | 2017 | 563 |
# | 2018 | 584 |
# | 2019 | ? |
#
# What is the forecast for 2019 with a **2-period simple moving average**?
#
# - 480
# - 488
# - 460
# - 520
# - 574
#
# ---
#
# ### Question 51
# Forecast 2019 notebook sales with a **3-period weighted moving average** (weights: 0.60 for 2018, 0.25 for 2017, 0.15 for 2016).
#
# | Year | Sales |
# |------|-------|
# | 2014 | 450 |
# | 2015 | 495 |
# | 2016 | 518 |
# | 2017 | 563 |
# | 2018 | 584 |
#
# Select the closest forecast:
#
# - 528
# - 569
# - 579
# - 584
# - 539
#
# ---
#
# ### Question 52
# Exponential smoothing with α = 0.40:
#
# | Year | Sales | Forecast |
# |------|-------|----------|
# | 2014 | 450 | 450 |
# | 2015 | 495 | 450 |
# | 2016 | 518 | 468 |
# | 2017 | 563 | 488 |
# | 2018 | 584 | ? |
# | 2019 | ? |
#
# First update the 2018 forecast, then compute the **2019 forecast**.
#
# - 490
# - 518
# - 528
# - 544
# - 553
#
# ---
#
# ### Question 53
# Exponential smoothing with α = 0.80:
#
# | Year | Sales | Forecast |
# |------|-------|----------|
# | 2014 | 450 | 450 |
# | 2015 | 495 | 450 |
# | 2016 | 518 | 468 |
# | 2017 | 563 | 488 |
# | 2018 | 584 | ? |
# | 2019 | ? |
#
# After updating the 2018 forecast, what is the **forecast for 2019**?
#
# - 490
# - 518
# - 528
# - 540
# - 577

# %% [markdown]
# ---
# ---
# ---

# %% [markdown]
# ### Question 54
# **Statement 1:** Increasing the salvage value of an item (all else equal) lowers the optimal service level in the newsvendor model.
# **Statement 2:** If the salvage value equals the unit acquisition cost, the critical fractile equals 1.
#
# - Only Statement 1 is True
# - Only Statement 2 is True
# - Both Statements are True
# - Both Statements are False
#
# ---
#
# ### Question 55
# **Statement 1:** In exponential-smoothing forecasts, raising the smoothing constant α always reduces the mean absolute deviation (MAD) when demand is strongly seasonal.
# **Statement 2:** A tracking-signal value of +4 generally indicates that the forecasting model is persistently under-predicting demand.
#
# - Only Statement 1 is True
# - Only Statement 2 is True
# - Both Statements are True
# - Both Statements are False
#
# ---
#
# ### Question 56
# **Statement 1:** In an EOQ system with non-zero safety stock, doubling annual demand D will more than double the annual ordering cost.
# **Statement 2:** Holding safety stock does not change the optimal EOQ calculated from the classic formula.
#
# - Only Statement 1 is True
# - Only Statement 2 is True
# - Both Statements are True
# - Both Statements are False
#
# ---
#
# ### Question 57
# **Statement 1:** Increasing replenishment frequency by ordering in smaller, more regular lots reduces the bullwhip effect.
# **Statement 2:** Sharing real-time POS data with upstream suppliers has no measurable impact on bullwhip amplification.
#
# - Only Statement 1 is True
# - Only Statement 2 is True
# - Both Statements are True
# - Both Statements are False
#
# ---
#
# ### Question 58
# **Statement 1:** A positive Mean Forecast Error (MFE) indicates that, on average, actual demand exceeds the forecast.
# **Statement 2:** Mean Absolute Deviation (MAD) reveals whether a forecasting method consistently over- or under-predicts demand.
#
# - Only Statement 1 is True
# - Only Statement 2 is True
# - Both Statements are True
# - Both Statements are False
#
# ---
#
# ### Question 59
# **Statement 1:** Introducing a buy-back agreement (where the manufacturer repurchases unsold units) lowers the retailer’s optimal order quantity compared with a pure wholesale-price contract.
# **Statement 2:** A buy-back contract can increase total supply-chain profit relative to a wholesale-price contract.
#
# - Only Statement 1 is True
# - Only Statement 2 is True
# - Both Statements are True
# - Both Statements are False
#
# ---
#
# ### Question 60
# **Statement 1:** For normally distributed demand, doubling lead time exactly doubles the safety-stock quantity required for a fixed cycle-service level.
# **Statement 2:** When demand variance is proportional to the square of the mean (constant coefficient of variation), safety stock as a *percentage* of mean lead-time demand decreases as lead time increases.
#
# - Only Statement 1 is True
# - Only Statement 2 is True
# - Both Statements are True
# - Both Statements are False

# %% [markdown]
# ## Answer Key and Explanations
#
# ---
#
# ### **Question 1**
# **Correct Answer:** E
# **Explanation:** A decentralized supply chain is suitable when there are many points of sale, allowing inventory to be located closer to customers. This improves service levels and reduces delivery times.
#
# ---
#
# ### **Question 2**
# **Correct Answers:** A, D
# **Explanation:**
# - A centralized strategy aligns with efficiency: fewer facilities, lower inventory, and scale economies.
# - A decentralized strategy supports responsiveness: localized inventory and quicker customer service.
# Other options confuse strategy-supply chain alignment.
#
# ---
#
# ### **Question 3**
# **Correct Answers:** B, C
# **Explanation:**
# - Exchange rate volatility adds financial risk, impacting cost predictability.
# - Loss of control over quality and cost is a common issue with remote vendors.
# Options A and D are less directly cited in the course as primary pitfalls.
#
# ---
#
# ### **Question 4**
# **Correct Answer:** C
# **Explanation:** Real estate costs are typically fixed and domestic, not a major factor in offshoring decisions. Other options reflect variable and international-specific cost elements.
#
# ---
#
# ### **Question 5**
# **Correct Answers:** A, D
# **Explanation:** Centralized supply chains are ideal when demand is predictable and distribution complexity is low. This allows fewer facilities to serve broad areas efficiently.
#
# ---
#
# ### **Question 6**
# **Correct Answer:** A
# **Explanation:** Although exchange rate fluctuations impact cost, the course classifies them under *Political and Macroeconomic Drivers*, not *Cost Drivers*. Falling communication costs, while reducing costs, are still categorized under cost drivers due to their direct influence on feasibility.
#
#
# ---
# ---
# ---
#
# ### **Question 7**
# **Correct Answers:** A, C, E
# **Explanation:**
# Responsive supply chains are designed for environments with:
# - **Rapid shifts in customer preferences** (A)
# - **Short product lifecycles** (C)
# - **High forecast uncertainty** (E)
# These conditions require flexibility, speed, and adaptability. Cost efficiency (B) and minimal customization (D) align more with efficient or lean models.
#
# ---
#
# ### **Question 8**
# **Correct Answers:** B, D, E
# **Explanation:**
# Decentralization is justified when:
# - **Multiple regions require tailored delivery** (B)
# - **Products are time-sensitive** (D)
# - **Demand is erratic and localized** (E)
# Long lead times (A) contradict decentralization logic, and low transport cost per unit (C) favors centralization due to economies of scale.
#
# ---
#
# ### **Question 9**
# **Correct Answers:** A, C, D
# **Explanation:**
# Offshoring exposes firms to:
# - **IP leakage risks** (A)
# - **Supply chain disruptions due to distance** (C)
# - **Exchange rate exposure** (D)
# Home wage inflation (B) and domestic union costs (E) are unrelated to offshore risk.
#
# ---
#
# ### **Question 10**
# **Correct Answer:** C
# **Explanation:**
# Centralized networks are:
# - Cost-efficient (A, B),
# - Easier to control (D),
# but **not** highly responsive to **local market fluctuations** (C) due to geographic and logistical lag.
#
# ---
#
# ### **Question 11**
# **Correct Answer:** B
# **Explanation:**
# **Exchange rate volatility** (B) is a hidden financial cost that can unpredictably erode offshoring gains. Other choices are either domestic costs or not hidden (like known logistics costs).
#
# ---
#
# ### **Question 12**
# **Correct Answer:** D
# **Explanation:**
# Offshoring **core competencies** may reduce internal expertise, innovation capacity, and strategic differentiation. That **weakens long-term competitive strength** (D).
#
# ---
#
# ### **Question 13**
# **Correct Answer:** C
# **Explanation:**
# Centralized supply chains emphasize:
# - **Efficiency** (C) through inventory pooling, scale economies, and standardization.
# They are less suited to responsiveness or agility.
#
# ---
#
# ### **Question 14**
# **Correct Answer:** C
# **Explanation:**
# The best strategic match is:
# - **Innovative product → Responsive supply chain** (C)
# These products have uncertain demand and benefit from speed, flexibility, and market feedback. Functional products match efficient supply chains.

# %% [markdown]
# ### **Question 15**
# **Correct Answer:** C. Critical fractile based on overage and underage cost
# **Explanation:**
# The newsvendor model determines the optimal one-time order quantity based on balancing the **cost of overstocking (CO)** and **understocking (CU)**. This balance is captured in the **critical fractile**:
# $$
# \text{Critical Fractile} = \frac{CU}{CU + CO}
# $$
# This ratio directly determines the service level and optimal order quantity.
#
# ---
#
# ### **Question 16**
# **Correct Answer:** C. Shortages are allowed
# **Explanation:**
# The basic EOQ model **does not** allow shortages. It assumes:
# - Constant demand
# - Instantaneous replenishment
# - No stockouts
# - Cost focus only on ordering and holding
# Allowing shortages would require a modified model.
#
# ---
#
# ### **Question 17**
# **Correct Answer:** B. EOQ decreases
# **Explanation:**
# The EOQ formula is:
# $$
# EOQ = \sqrt{\frac{2DS}{H}}
# $$
# If holding cost ($H$) increases, the denominator increases, causing the EOQ value to decrease. This means firms should order smaller quantities more frequently when it becomes more expensive to hold inventory.
#
# ---
#
# ### **Question 18**
# **Correct Answer:** B. Holding and ordering
# **Explanation:**
# EOQ is derived by minimizing the **sum** of:
# - **Ordering costs** (cost incurred per order placed)
# - **Holding costs** (cost to carry inventory over time)
# Other costs like shrinkage, spoilage, or transportation are excluded in the basic EOQ model.
#
# ---
#
# ### **Question 19**
# **Correct Answer:** C. Because excess inventory is kept to avoid stockouts
# **Explanation:**
# Achieving a 100% fill rate requires **buffering against all demand uncertainty**, which leads to carrying large amounts of safety stock. This increases **holding costs** significantly and is typically not optimal in cost-sensitive environments.
#
# ---
#
# ### **Question 20**
# **Correct Answer:** A. It represents the lost margin on a missed sale
# **Explanation:**
# In a newsvendor setting, the **underage cost (CU)** is calculated as the **contribution margin lost** when demand exceeds inventory. This is approximated as:
# $$
# CU = \text{Retail Price} - \text{Wholesale Cost}
# $$
# It reflects the opportunity cost of failing to meet demand.

# %% [markdown]
# ___
# ___
# ___

# %% [markdown]
# ### Question 21
# **Correct Answer:** 196
# **Explanation:**
# Annual demand = 400 × 12 = 4,800 units
# EOQ formula:
# $EOQ = \sqrt{\frac{2DS}{H}} = \sqrt{\frac{2 \times 4800 \times 40}{10}} = \sqrt{38400} = 196$
#
# ---
#
# ### Question 22
# **Correct Answer:** 331
# **Explanation:**
# Annual demand = 7,950 cars
# Standard deviation of demand = 280 cars
# Service level Z = 1.29
# Lead time = 12 days
# Daily demand = 7,950 / 360 = 22.08
# Average demand during lead time = 22.08 × 12 = 265
# Safety stock = $1.29 \times 280 \times \sqrt{12/360} = 1.29 \times 280 \times \sqrt{1/30} \approx 66$
# ROP = 265 + 66 = **331**
#
# ---
#
# ### Question 23
# **Correct Answer:** 200
# **Explanation:**
# EOQ = $\sqrt{\frac{2 \times 1000 \times 10}{0.5}} = \sqrt{40000} = 200$
#
# ---
#
# ### Question 24
# **Correct Answer:** C. To produce only when there is downstream demand
# **Explanation:**
# Pull systems are demand-driven. Production is triggered by actual consumption downstream to minimize excess inventory and overproduction.
#
# ---
#
# ### Question 25
# **Correct Answer:** False
# **Explanation:**
# Pull systems aim to minimize inventory by producing only in response to demand. Push systems typically hold more inventory to buffer uncertainty.
#
# ---
#
# ### Question 26
# **Correct Answer:** C. Producing at the rate of customer demand
# **Explanation:**
# Lean emphasizes alignment with customer demand and eliminating waste, not batching or maximizing utilization.
#
# ---
#
# ### Question 27
# **Correct Answer:** True
# **Explanation:**
# Push systems are forecast-driven and can result in overproduction, leading to higher inventory and associated holding costs.
#
# ---
#
# ### Question 28
# **Correct Answer:** C. Running a time-limited discount
# **Explanation:**
# This is a demand-side lever because it aims to shift or increase customer demand, helping to align it with available supply.

# %% [markdown]
# ### Question 28  (b - unrelated to previous 28)
# **Correct Answer:** B. The ratio of underage cost to total marginal cost
# **Explanation:**
# The critical fractile in the newsvendor model is defined as:
# $$
# \text{Critical Fractile} = \frac{CU}{CU + CO}
# $$
# where $CU$ is the underage cost (cost of ordering too little), and $CO$ is the overage cost (cost of ordering too much).
#
# ---
#
# ### Question 29
# **Correct Answer:** A. 1 : 4
# **Explanation:**
# Given $CF = 0.80$, we use:
# $$
# 0.80 = \frac{CU}{CU + CO} \Rightarrow \frac{CO}{CU} = 0.25
# $$
# Thus, the ratio $CO : CU = 1 : 4$.
#
# ---
#
# ### Question 30
# **Correct Answer:** B. Increases it
# **Explanation:**
# A buy-back program increases the salvage value of unsold goods, which lowers the overage cost $CO$. Since the critical fractile is:
# $$
# CF = \frac{CU}{CU + CO}
# $$
# a lower $CO$ results in a higher $CF$, increasing the optimal order quantity.
#
# ---
#
# ### Question 31
# **Correct Answer:** C. Variance ratio of orders to sales
# **Explanation:**
# The bullwhip effect is measured by the amplification of variability as you move upstream in a supply chain. A common metric is:
# $$
# \frac{\text{Var(Orders)}}{\text{Var(Sales)}}
# $$
# Higher values indicate greater distortion and volatility.
#
# ---
#
# ### Question 32
# **Correct Answer:** E. Use USD 10 supplier if total cost is minimized
# **Explanation:**
# Compare total costs:
# $$
# \text{Total Cost} = \text{Purchase} + \text{Ordering} + \text{Holding}
# $$
# The USD 10 option is better only if it results in a lower total cost, not just based on EOQ.
#
# ---
# ### Question 33
# **Correct Answer:** _None of the above_
# **Explanation:**
# - Purchase cost = USD 25
# - Selling price = USD 40
# - Salvage = USD 0 (donated)
# Then:
# $$
# CU = 40 - 25 = 15, \quad CO = 25 - 0 = 25
# $$
# $$
# CF = \frac{15}{15 + 25} = \frac{15}{40} = 0.375
# $$
# Since 0.375 is not a listed option, the correct answer is **none of the above**.

# %% [markdown]
# ### Question 33
# **Correct Answer:** items with a long selling season
# **Explanation:**
# The newsvendor model suits products sold in a single, short season (e.g., perishables, holiday goods). Items with long selling seasons allow multiple replenishments, so continuous-review models work better.
#
# ---
#
# ### Question 34
# **Correct Answer:** 0.43
# **Explanation:**
# - Purchase cost = USD 0.75
# - Selling price = USD 1.25 ⟹ CU (underage cost) = 1.25 − 0.75 = 0.50
# - Salvage value = USD 0.10 ⟹ CO (overage cost) = 0.75 − 0.10 = 0.65
#
# Critical fractile
# CF = CU / (CU + CO) = 0.50 / (0.50 + 0.65) ≈ 0.43.
#
# ---
#
# ### Question 35
# **Correct Answer:** 91 %
# **Explanation:**
# Integrated CU = 11.50 − 1.00 = 10.50 (lost margin if under-stocked).
# CO = 1.00 (unit cost lost if over-stocked).
# CF = 10.50 / (10.50 + 1.00) ≈ 0.91 → 91 %.
#
# ---
#
# ### Question 36
# **Correct Answer:** 61 %
# **Explanation:**
# For the retailer:
# CU = 11.50 − 4.50 = 7.00
# CO = 4.50 (no salvage)
# CF = 7.00 / (7.00 + 4.50) ≈ 0.61.
#
# ---
#
# ### Question 37
# **Correct Answer:** 64 %
# **Explanation:**
# New salvage value to retailer = USD 0.50.
# CO = 4.50 − 0.50 = 4.00
# CU remains 7.00.
# CF = 7.00 / (7.00 + 4.00) ≈ 0.64.
#
# ---
#
# ### Question 38
# **Correct Answer:** 53 %
# **Explanation (Jimmy):**
# CU (profit loss when short) = (10 − 4.20) − (10 − 8.90) = 5.80 − 1.10 = 4.70
# CO = 4.20 (discarded).
# CF = 4.70 / (4.70 + 4.20) ≈ 0.53 → 53 %.
#
# ---
#
# ### Question 39
# **Correct Answer:** 55 %
# **Explanation (Bob):**
# Wholesale profit if in stock = 11 − 4.50 = 6.50
# Profit when short (courier) = 1.00
# CU = 6.50 − 1.00 = 5.50
# CO = 4.50
# CF = 5.50 / (5.50 + 4.50) = 0.55 → 55 %.
#
# ---
#
# ### Question 40
# **Correct Answer:** 30
# **Explanation (Bill’s calendars):**
# Unit cost = 27 / 10 = USD 2.70
# Selling price = USD 5.79 ⟹ CU = 5.79 − 2.70 = 3.09
# Salvage = USD 0.50 ⟹ CO = 2.70 − 0.50 = 2.20
# CF = 3.09 / (3.09 + 2.20) ≈ 0.584
#
# Cumulative demand probabilities:
# - ≤10 = 0.30
# - ≤20 = 0.55
# - ≤30 = 0.75 (first ≥ 0.584)
#
# Order the first lot size reaching the CF threshold: **30 calendars**.

# %% [markdown]
# ### Question 41
# **Answer:** 0.43
# **Explanation:**
# CU (underage) = 1.25 − 0.75 = 0.50
# CO (overage) = 0.75 − 0.10 = 0.65
# Critical fractile = 0.50 / (0.50 + 0.65) ≈ **0.43**
#
# ---
#
# ### Question 42
# **Answer:** 91 %
# **Explanation:**
# Integrated CU = 11.50 − 1.00 = 10.50
# Integrated CO = 1.00 (unsold widgets have no value)
# Service level = 10.50 / (10.50 + 1.00) ≈ **91 %**
#
# ---
#
# ### Question 43
# **Answer:** 64 %
# **Explanation:**
# Retailer CU = 11.50 − 4.50 = 7.00
# New CO = 4.50 − 0.50 = 4.00
# Service level = 7.00 / (7.00 + 4.00) ≈ **64 %**
#
# ---
#
# ### Question 44
# **Answer:** More trade regulations and tariffs
# **Explanation:**
# Firms offshore to lower costs, access talent, or reach markets. Stricter regulations and higher tariffs discourage, not encourage, off-shoring.
#
# ---
#
# ### Question 45
# **Answer:** “the cost of being over is C − S”
# **Explanation:**
# In the newsvendor setup the per-unit overage cost equals acquisition cost minus salvage value. None of the other listed statements match the standard overage definition.
#
# ---
#
# ### Question 46
# **Answer:** 45 %
# **Explanation:**
# CU = 7.00 − 3.90 = 3.10
# CO = 3.90 (no salvage)
# Service level = 3.10 / (3.10 + 3.90) ≈ 0.443 → round up → **45 %**
#
# ---
#
# ### Question 47
# **Answer:** USD 2 736
# **Explanation:**
# - H = 10 % × 24.75 = 2.475 USD/unit/year
# - EOQ = √(2 × 4 500 × 275 / 2.475) = 1 000 units
# - Orders per year = 4 500 / 1 000 = 4.5 → round up to 5 orders
# - Ordering cost = 5 × 275 = 1 375 USD
# - Holding cost on cycle stock = (1 000 / 2) × 2.475 = 1 237.50 USD
# - Holding cost on safety stock = 50 × 2.475 = 123.75 USD
# Total inventory cost = 1 375 + 1 237.50 + 123.75 = **USD 2 736**

# %% [markdown]
# ### Question 48
# **Answer:** 555
# **Explanation:**
# 3-period simple moving average (SMA) for 2019 uses 2018, 2017, 2016 sales:
# (584 + 563 + 518) / 3 = 1665 / 3 = 555.
#
# ---
#
# ### Question 49
# **Answer:** 488
# **Explanation:**
# 3-period SMA forecast for 2017 uses 2016, 2015, 2014 sales:
# (518 + 495 + 450) / 3 = 1463 / 3 ≈ 488.
#
# ---
#
# ### Question 50
# **Answer:** 574
# **Explanation:**
# 2-period SMA forecast for 2019 uses 2018 and 2017:
# (584 + 563) / 2 = 1147 / 2 = 573.5 ≈ 574.
#
# ---
#
# ### Question 51
# **Answer:** 569
# **Explanation:**
# Weighted moving average (weights 0.60-0.25-0.15):
# 0.60 × 584 = 350.4
# 0.25 × 563 = 140.75
# 0.15 × 518 = 77.70
# Sum = 568.85 ≈ 569.
#
# ---
#
# ### Question 52
# **Answer:** 544
# **Explanation:**
# Exponential smoothing, α = 0.40.
# • 2018 forecast: 488 + 0.40 × (563 − 488) = 488 + 30 = 518.
# • 2019 forecast: 518 + 0.40 × (584 − 518) = 518 + 26.4 ≈ 544.
#
# ---
#
# ### Question 53
# **Answer:** 577
# **Explanation:**
# Exponential smoothing, α = 0.80.
# • 2018 forecast: 488 + 0.80 × (563 − 488) = 488 + 60 = 548.
# • 2019 forecast: 548 + 0.80 × (584 − 548) = 548 + 28.8 ≈ 577.

# %% [markdown]
# ### Question 54
# **Correct Choice:** Only Statement 2 is True
#
# | Statement | Evaluation | Reason |
# |-----------|------------|--------|
# | 1 | False | Raising salvage value lowers the overage cost CO, which **raises** (not lowers) the critical fractile and service level. |
# | 2 | True  | If salvage value = unit cost → CO = 0, so CF = CU / (CU + 0) = 1, giving a 100 % service level. |
#
# ---
#
# ### Question 55
# **Correct Choice:** Only Statement 2 is True
#
# | Statement | Evaluation | Reason |
# |-----------|------------|--------|
# | 1 | False | A higher α makes a forecast more sensitive; with strong seasonality but no seasonal adjustment it can **increase** error. |
# | 2 | True  | Tracking-signal = RSFE / MAD. A positive RSFE means Actual > Forecast, so TS = +4 signals persistent **under-forecasting**. |
#
# ---
#
# ### Question 56
# **Correct Choice:** Only Statement 2 is True
#
# | Statement | Evaluation | Reason |
# |-----------|------------|--------|
# | 1 | False | Annual ordering cost = (D / Q) × S. Doubling D doubles the cost (linear), not **more** than doubles it. |
# | 2 | True  | Classic EOQ = √(2DS / H) and does **not** include safety stock; adding safety stock leaves EOQ unchanged. |
#
# ---
#
# ### Question 57
# **Correct Choice:** Only Statement 1 is True
#
# | Statement | Evaluation | Reason |
# |-----------|------------|--------|
# | 1 | True  | Smaller, more frequent orders smooth demand seen upstream, reducing order-batch amplification. |
# | 2 | False | Real-time POS sharing mitigates information delay and **does** reduce bullwhip magnitude. |
#
# ---
#
# ### Question 58
# **Correct Choice:** Only Statement 1 is True
#
# | Statement | Evaluation | Reason |
# |-----------|------------|--------|
# | 1 | True  | With error defined as Actual − Forecast, a positive MFE implies actual demand exceeds forecast on average. |
# | 2 | False | MAD discards error signs; it measures size, not bias, so it cannot reveal over- vs. under-prediction direction. |
#
# ---
#
# ### Question 59
# **Correct Choice:** Only Statement 2 is True
#
# | Statement | Evaluation | Reason |
# |-----------|------------|--------|
# | 1 | False | Buy-back raises salvage value → lower CO → higher CF → retailer orders **more**, not less. |
# | 2 | True  | Buy-back contracts better align incentives and usually increase total supply-chain profit versus a pure wholesale price. |
#
# ---
#
# ### Question 60
# **Correct Choice:** Only Statement 2 is True
#
# | Statement | Evaluation | Reason |
# |-----------|------------|--------|
# | 1 | False | Safety stock ∝ √Lead Time; doubling lead time multiplies safety stock by √2 (≈1.414), **not** by 2. |
# | 2 | True  | With constant coefficient of variation, safety stock / mean = Z · CV / √L, which **declines** as lead time L increases. |
