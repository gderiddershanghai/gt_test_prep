# %% [markdown]
# ## Question 17
# What’s the period of the generator $X_i = (3X_{i-1} + 2) \mod 5$ if we use the seed $X_0 = 3$?
#
# ### Solution:
# Note that $X_0 = 3$, $X_1 = 1$, $X_2 = 0$, $X_3 = 2$, $X_4 = 3$, so the period is 4.
#
# (Interestingly, $X_0 = 4$ would have caused an immediate degenerate cycle.)
#
# ---
#
# ## Question 18
# TRUE or FALSE? The generator $X_i = (32X_{i-1} + 124) \mod 2048$ has full period.
#
# ### Solution:
# FALSE. (You get all evens.)
#
# ---
#
# ## Question 19
# Which uniform generator was recommended in class, at least as a “desert island” generator?
#
# (a) $X_i = 16807 X_{i-1} \mod (2^{31})$
#
# (b) $X_i = 16807 X_{i-1} \mod (2^{31} - 1)$
#
# (c) $X_i = 16807 (X_{i-1} - 1) \mod (2^{31})$
#
# (d) $X_i = 16807 (X_{i-1} - 1) \mod (2^{31} - 1)$
#
# ### Solution:
# The correct answer is **(b)**.
#
# ---
#
# ## Question 27
# Suppose that we have a sequence of $n = 100$ PRN’s, and we observe 70 runs up and down. Using $\alpha = 0.01$, do we ACCEPT (i.e., fail to reject) or REJECT the null hypothesis of independence?
#
# ### Solution:
# The answer depends on performing the necessary hypothesis test, but essentially, you would compare the calculated test statistic to critical values.
#
# ---
#
# ## Question 28
# We are testing a certain COVID vaccine. Our null hypothesis is the assumption that the vaccine is safe. If we accept this null hypothesis but the medication is actually harmful, what type of error have we committed?
#
# ### Solution:
# The correct answer is **Type I Error**.
#
# ---
#
# ## Question 4
# Consider the PRN generator $X_{i+1} = (aX_i + 5) \mod b$. Using $X_0 = 0$, which values of $a$ and $b$ yield a cycle length of 4?
#
# (a) $a = 1, b = 2$
# (b) $a = 3, b = 4$
# (c) $a = 3, b = 6$
# (d) $a = 3, b = 8$
#
# ### Solution:
# By inspection (plugging the values in), we find that (d) is the only answer that works.
#
# ---
#
# ## Question 5
# Consider our desert island generator $X_{i+1} = 16807 X_i \mod (2^{31} - 1)$. If $X_0 = 1234321$, find the value of $X_1$.
#
# (a) 0
# (b) 0.61359
# (c) 25,152,971
# (d) 116,194,254
# (e) 1,417,880,224
# (f) $2^{31} - 582$
#
# ### Solution:
# By hook or by crook (e.g., by the algorithm given in the notes), we find that $X_1 = 1,417,880,224$, so that the answer is **(e)**.
#
# ---
#
# ## Question 6
# What is $(0 \ \text{XOR} \ 1) \ \text{XOR} \ (1 \ \text{XOR} \ 1)$?
#
# (a) 0
# (b) 1
# (c) 2
# (d) 4
#
# ### Solution:
# $(0 \ \text{XOR} \ 1) \ \text{XOR} \ (1 \ \text{XOR} \ 1) = 1 \ \text{XOR} \ 0 = 1$. The answer is **(b)**.
#
# ---
#
# ## Question 7
# Consider a Tausworthe generator with $r = 1$, $q = 3$, $B_1 = 1$, $B_2 = 1$, and $B_3 = 1$. Find $B_{39}$.
#
# (a) 0
# (b) 1
# (c) 2
# (d) 4
#
# ### Solution:
# $B_i = B_{i-r} \ \text{XOR} \ B_{i-q} = B_{i-1} \ \text{XOR} \ B_{i-3}$. Thus,
#
# $B_4 = B_3 \ \text{XOR} \ B_1 = 1 \ \text{XOR} \ 1 = 0$
# $B_5 = B_4 \ \text{XOR} \ B_2 = 0 \ \text{XOR} \ 1 = 1$
# $B_6 = B_5 \ \text{XOR} \ B_3 = 1 \ \text{XOR} \ 1 = 0$
# $B_7 = B_6 \ \text{XOR} \ B_4 = 0 \ \text{XOR} \ 0 = 0$
# $B_8 = B_7 \ \text{XOR} \ B_5 = 0 \ \text{XOR} \ 1 = 1$
# $B_9 = B_8 \ \text{XOR} \ B_6 = 1 \ \text{XOR} \ 0 = 1$
# $B_{10} = B_9 \ \text{XOR} \ B_7 = 1 \ \text{XOR} \ 0 = 1$
#
# So we see that the thing starts a new cycle at $B_8$, and $B_{39} = B_32 = \cdots = B_4 = 0$. Thus, the answer is **(a)**.
#
# ---
#
# ## Question 8
# TRUE or FALSE? There are various PRN generators out there having periods greater than $2^{19000}$, but since those periods are so big we can’t really use such generators at all.
#
# ### Solution:
# FALSE. The period only describes how long it takes for the generator to cycle, but doesn’t have an effect on generating the PRNs or the quality of the PRNs.
#
# ---
#
# ## Question 9
# Suppose that we have a sequence of $n = 100$ PRN’s, and we observe 80 runs up and down. Using $\alpha = 0.05$, do we ACCEPT (i.e., fail to reject) or REJECT the null hypothesis of independence?
#
# ### Solution:
# By class notes, under the null hypothesis of independence, $A \approx \text{Nor}\left(\frac{2n-1}{3}, \frac{16n-29}{90}\right) \sim \text{Nor}(66.33, 17.46)$. Thus, the test statistic is:
# $$
# Z_0 = \frac{A - E[A]}{\sqrt{\text{Var}(A)}} = \frac{80 - 66.33}{\sqrt{17.46}} = 3.27.
# $$
#
# Since $|Z_0| > z_{\alpha/2} = 1.96$, we REJECT $H_0$. In other words, we conclude that they’re not independent.
#
# ---
#
# ## Question 10
# Suppose we sample 1000 PRN’s and we wish to conduct a $\chi^2$ goodness-of-fit test at level $\alpha = 0.10$ of the hypothesis that the numbers are $\text{Unif}(0,1)$. Here are the results, divided into 4 intervals (conveniently chosen to be equal-probability intervals under $H_0$):
#
# | interval | $O_i$ |
# |----------|-------|
# | [0.00, 0.25] | 275 |
# | [0.25, 0.50] | 250 |
# | [0.50, 0.75] | 250 |
# | [0.75, 1.00] | ?? |
#
# Use the tabled results to find the value of the g-o-f statistic, $\chi_0^2$.
#
# (a) 0
# (b) 5
# (c) 25
# (d) 125
# (e) 250
#
# ### Solution:
# We begin with a trivial completion of the table (to take into account the missing “??”):
#
# | interval | $O_i$ |
# |----------|-------|
# | [0.00, 0.25] | 275 |
# | [0.25, 0.50] | 250 |
# | [0.50, 0.75] | 250 |
# | [0.75, 1.00] | 225 |
#
# Since we have $k = 4$ equiprobable intervals, we obtain $E_i = n/k = 250$ for all $i$.
#
# Thus,
# $$
# \chi_0^2 = \sum_{i=1}^{k} \frac{(O_i - E_i)^2}{E_i} = \sum_{i=1}^{4} \frac{(O_i - 250)^2}{250} = 5.0,
# $$
# and so the answer is **(b)**.

# %% [markdown]
# ## Question 11
# Similar to Problem 10, let’s do a $\chi^2$ test for uniformity with $n = 1000$ PRN’s, $k = 4$ equiprobability intervals, and level $\alpha = 0.10$. But now suppose it turns out that $\chi_0^2 = 10$ (instead of whatever answer you got before). Do we ACCEPT (i.e., fail to reject) or REJECT the null hypothesis of uniformity?
#
# ### Solution:
# First of all, the appropriate test quantile is $\chi^2_{\alpha, k-1} = \chi^2_{0.10,3} = 6.25$. Since $\chi_0^2 > \chi^2_{\alpha, k-1}$, we REJECT uniformity.
#
# ---
#
# ## Question 11
# (Lesson 6.3: Linear Congruential Generators. Problem 7.1 from Law 2015). Consider the generator:
# $$ X_i = (5X_{i-1} + 3) \mod 16 $$.
# Starting from $X_0 = 7$, find $X_{500}$.
#
# ### Solution:
# If $X_0 = 7$, then $X_1 = 38 \mod 16 = 6$, $X_2 = 1$, $X_3 = 8$, ..., $X_{16} = 7$. So the cycle repeats itself every 16 iterations. This implies that $X_{32} = 7 = X_48 = \cdots = X_{496}$, and so $X_{500} = X_{496+4} = X_4 = 11$. So the answer is (d).
#
# ---
#
# ## Question 18
# (Lesson 6.9: Runs Tests for Independence.) Consider the following $n = 30$ PRNs. (Read from left to right, and then down.)
#
# $$
# 0.79, 0.68, 0.46, 0.69, 0.90, 0.93, 0.99, 0.86, 0.33, 0.22, 0.60, 0.18, 0.59, 0.38, 0.69, 0.76, 0.91, 0.68, 0.62, 0.22, 0.19
# $$
#
# Let’s conduct a runs up and down test to test $H_0$: the $U_i$’s are independent with level $\alpha = 0.05$. ACCEPT or REJECT?
#
# ### Solution:
# Let’s associate $+$ and $-$ for up and down, respectively. Then the 30 PRNs translate to:
# $$
# - + + + + + - - + + + + + - - + + + + - + + - + + + + - + - + + + -
# $$
# so that we have $A = 12$ runs up and down.
#
# Recall that:
# $$
# A \sim \text{Nor}\left( \frac{2n-1}{3}, \frac{16n-29}{90} \right) \sim \text{Nor}(19.67, 5.01)
# $$
#
# Thus, the test statistic is:
# $$
# Z_0 = \frac{A - E[A]}{\sqrt{\text{Var}(A)}} = \frac{12 - 19.67}{\sqrt{5.01}} = -3.43
# $$
#
# Meanwhile, the appropriate quantile is $z_{\alpha/2} = 1.96$. Since $|Z_0| > z_{\alpha/2}$, we REJECT $H_0$. In other words, these fellows probably ain't independent.
#
# ---
#
# ## Question 19
# (Lesson 6.9: Runs Tests for Independence.) Suppose that $U_1, U_2, U_3$ are i.i.d. $\text{Unif}(0,1)$. Let’s denote the number of runs up-and-down by $X$. Find the EXACT distribution of $X$.
#
# ### Solution:
# We write out every possible outcome of the relationship of the three $U_i$'s, each of which will have equal probability of occurring:
#
# | Event | Runs | Number of runs |
# |-------|------|----------------|
# | $U_1 < U_2 < U_3$ | ++ | 1 |
# | $U_1 < U_3 < U_2$ | +- | 2 |
# | $U_2 < U_1 < U_3$ | -+ | 2 |
# | $U_2 < U_3 < U_1$ | ++ | 2 |
# | $U_3 < U_1 < U_2$ | -- | 1 |
# | $U_3 < U_2 < U_1$ | -- | 1 |
#
# Hence, in the case of three PRNs, there is 1 run with probability 1/3 and 2 runs with probability 2/3. Thus, the answer is (e).
#
# ---
#
# ## Question 21
# Consider the linear congruential generator $X_{i+1} = (5X_i + 3) \mod 12$. Using $X_0 = 0$, calculate the 46th integer $X_{46}$.
#
# ### Solution:
# (Work out the iterations or cycle length and find $X_{46}$).
#
# ---
#
# ## Question 22
# Regarding Linear Congruential Generators (LCG’s), select the statement that is correct.
#
# ### Solution:
# The correct answer is **(b)**.
#
# ---
#
# ## Question 23
# Consider our desert island generator $X_{i+1} = 16807 X_i \mod(231 - 1)$. If $X_0 = 123456789$, find the value of the second PRN, $U_2$.
#
# ### Solution:
# The correct answer is **(d)**.
#
# ---
#
# ## Question 24
# Suppose that a Tausworthe generator gave you the series of six bits 110111. If you use all of these bits, what $\text{Unif}(0,1)$ random number would that translate to?
#
# ### Solution:
# The correct answer is **(c)**.
#
# ---
#
# ## Question 25
# Consider the following sequence of PRN’s.
#
# $$
# 0.98, 0.95, 0.23, 0.17, 0.12, 0.03, 0.47, 0.83, 0.63, 0.72, 0.43, 0.52
# $$
#
# How many runs above and below the mean (0.5) does this sequence have?
#
# ### Solution:
# The correct answer is **(c)**.
#
# ---
#
# ## Question 26
# Suppose $U_1, U_2, U_3, U_4$ are i.i.d. $\text{Unif}(0,1)$. What is the probability that we will see exactly 1 run up and down?
#
# ### Solution:
# The correct answer is **(a)**.

# %% [markdown]
# ## Question 9
# Suppose that we have a sequence of $n = 100$ PRN’s, and we observe 80 runs up and down. Using $\alpha = 0.05$, do we ACCEPT (i.e., fail to reject) or REJECT the null hypothesis of independence?
#
# ### Solution:
# By class notes, under the null hypothesis of independence, $A \approx \text{Nor}\left(\frac{2n-1}{3}, \frac{16n-29}{90}\right) \sim \text{Nor}(66.33, 17.46)$. Thus, the test statistic is:
# $$
# Z_0 = \frac{A - E[A]}{\sqrt{\text{Var}(A)}} = \frac{80 - 66.33}{\sqrt{17.46}} = 3.27
# $$
#
# Since $|Z_0| > z_{\alpha/2} = 1.96$, we REJECT $H_0$. In other words, we conclude that they’re **not independent**. ✨
#
# ---
#
# ## Question 4
# Again consider the generator $X_i = (5X_{i-1} + 3) \mod 8$, initialized with $X_0 = 3$. Find $X_8$.
#
# ### Solution:
# According to the class notes (or via a bit of tedious algebra), we know that this is a full-period generator with a cycle length of 8. Therefore, $X_0 = X_8 = 3$. So the answer is (b).
#
# ---
#
# ## Question 5
# TRUE or FALSE? $(1 \oplus 1) \oplus 1 = 1$.
#
# ### Solution:
# We have:
# $$(1 \oplus 1) \oplus 1 = 0 \oplus 1 = 1; \text{ so the answer is TRUE.}$$
#
# ---
#
# ## Question 6
# Consider a Tausworthe generator that produces the bits $1,1,0,1,1$. Calculate the resulting pseudo-random number obtained by transforming these 5 bits from base 2 to base 10, i.e., $(11011)_2/2^5$, where $(x)_2$ denotes a number $x$ in base 2, e.g. $(101)_2 = 5$.
#
# ### Solution:
# $$(11011)_2 = 16 + 8 + 2 + 1 = 27 \quad \text{so the answer is} \quad \frac{27}{32}.$$
#
# ---
#
# ## Question 9
# TRUE or FALSE? $\alpha = P(\text{Reject } H_0 | H_0 \text{ is true})$ is the probability of a Type I error.
#
# ### Solution:
# TRUE. $\alpha$ is the probability of rejecting $H_0$ when $H_0$ is true (Type I error).
#
# ---
#
# ## Question 12
# Consider the following sequence of pseudo-random numbers:
# $0.15, 0.85, 0.23, 0.36, 0.42, 0.49, 0.66, 0.70, 0.81, 0.89, 0.97, 0.85$.
# How many runs "up and down" are there?
#
# ### Solution:
# Here is what the runs resulting from the 12 PRNs look like:
# $$
# + - + - + + + + - + + - + -
# $$
# Thus, there are 4 runs, so the answer is (c).
#
# ---
#
# ## Question 20
# Suppose that a Tausworthe generator gave you the series of bits $1010101$. If you use all 7 bits, what $\text{Unif}(0,1)$ random number would that translate to?
#
# ### Solution:
# Using the usual base-2 notation, we have:
# $$
# 1010101_2 = 64 + 16 + 4 + 1 = 85
# $$
# $$
# \frac{85}{128} = 0.6641
# $$
#
# ---
#
# ## Question 21
# Suppose we observe 1000 numbers to obtain the following data.
#
# | Interval | [0.00, 0.25) | [0.25, 0.50) | [0.50, 0.75) | [0.75, 1.0] |
# |----------|--------------|--------------|--------------|-------------|
# | Number observed | 240 | 255 | 243 | 262 |
#
# Conduct a $\chi^2$ goodness-of-fit test to see if these numbers are approximately $\text{Unif}(0,1)$. Use level of significance $\alpha = 0.05$. Here are some table entries that you may need: $\chi^2_{0.05,3} = 7.81$, $\chi^2_{0.05,4} = 9.49$, and $\chi^2_{0.05,5} = 11.1$. ACCEPT or REJECT?
#
# ### Solution:
# The expected number of observations per equal-probability cell is $E_i = \frac{1000}{4} = 250$. This gives us the following augmented table.
#
# | Interval | [0.00, 0.25) | [0.25, 0.50) | [0.50, 0.75) | [0.75, 1.0] |
# |----------|--------------|--------------|--------------|-------------|
# | Observed number $O_i$ | 240 | 255 | 243 | 262 |
# | Expected number $E_i$ | 250 | 250 | 250 | 250 |
#
# Thus, the $\chi^2$ goodness-of-fit statistic is:
# $$
# \chi^2_0 = \sum_{i=1}^4 \frac{(O_i - E_i)^2}{E_i} = \frac{(240-250)^2}{250} + \frac{(255-250)^2}{250} + \frac{(243-250)^2}{250} + \frac{(262-250)^2}{250} = 1.272
# $$
#
# Meanwhile, the appropriate quantile is $\chi^2_{\alpha,4} = \chi^2_{0.05,3} = 7.81$. Since $\chi^2_0 < \chi^2_{\alpha,4}$, we ACCEPT $H_0$. In other words, we assume that the numbers are approximately $\text{Unif}(0,1)$.
#
# ---
#
# ## Question 22
# Consider the following $n = 30$ PRNs. (Read from left to right, and then down.)
#
# $$
# 0.79, 0.68, 0.46, 0.69, 0.90, 0.03, 0.99, 0.86, 0.33, 0.22, 0.60, 0.18, 0.59, 0.38, 0.69, 0.76, 0.91, 0.68, 0.62, 0.22, 0.19
# $$
#
# Let’s conduct a runs up and down test to test $H_0$: the $U_i$’s are independent with level $\alpha = 0.05$. ACCEPT or REJECT?
#
# ### Solution:
# Let’s associate $+$ and $-$ for up and down, respectively. Then the 30 PRNs translate to:
# $$
# - + + + + + - - + + + + + - - + + + + - + + - + + + + - + - + + + -
# $$
# so that we have $A = 12$ runs up and down.
#
# Recall that:
# $$
# A \sim \text{Nor}\left(\frac{2n-1}{3}, \frac{16n-29}{90}\right) \sim \text{Nor}(19.67, 5.01)
# $$
#
# Thus, the test stat is:
# $$
# Z_0 = \frac{A - E[A]}{\sqrt{\text{Var}(A)}} = \frac{12 - 19.67}{\sqrt{5.01}} = -3.43
# $$
#
# Meanwhile, the appropriate quantile is $z_{\alpha/2} = 1.96$. Since $Z_0 < -1.96$, we REJECT $H_0$. In other words, these fellows probably ain't independent.
#
# ---
#
# ## Question 4
# Consider the PRN generator $X_{i+1} = (aX_i + 5) \mod b$. Using $X_0 = 0$, which values of $a$ and $b$ yield a cycle length of 4?
#
# ### Solution:
# By inspection (plugging the values in), we find that (d) is the only answer that works.
#
# ---
#
# ## Question 5
# Consider our desert island generator $X_{i+1} = 16807 X_i \mod(2^{31} - 1)$. If $X_0 = 1234321$, find the value of $X_1$.
#
# ### Solution:
# By hook or by crook (e.g., by the algorithm given in the notes), we find that $X_1 = 1,417,880,224$, so that the answer is (e).
#
# ---
#
# ## Question 6
# What is $(0 \oplus 1) \oplus (1 \oplus 1)$?
#
# ### Solution:
# $$(0 \oplus 1) \oplus (1 \oplus 1) = 1 \oplus 0 = 1; \text{ so the answer is (b)}$$
#
# ---
#
# ## Question 7
# Consider a Tausworthe generator with $r = 1$, $q = 3$, $B_1 = 1$, $B_2 = 1$, and $B_3 = 1$. Find $B_{39}$.
#
# ### Solution:
# $$
# B_i = B_{i-r} \oplus B_{i-q} = B_{i-1} \oplus B_{i-3}.
# $$
# Thus, following this recursion:
# $$
# B_4 = B_3 \oplus B_1 = 1 \oplus 1 = 0, \quad B_5 = B_4 \oplus B_2 = 0 \oplus 1 = 1, \quad \ldots, \quad B_{39} = B_4 = 0.
# $$
# So the answer is (a).
#
# ---
#
# ## Question 8
# Consider the PRN generator $X_{i+1} = (aX_i + 5) \mod 6$. Find the cycle length for this generator.
#
# ### Solution:
# The cycle length for this generator can be determined by trying different values for $a$. You can find that the cycle length is 6. Thus, the answer is (d).
#
# ---
#
# ## Question 9
# What is the probability of a Type I error?
#
# ### Solution:
# The probability of a Type I error is denoted as $\alpha$ and is the probability of rejecting $H_0$ when $H_0$ is true. Thus, the answer is (a).
#
# ---
#
# Let me know if you need anything else or more questions!
